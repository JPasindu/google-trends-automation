# %%
import pandas as pd

# %%
df1=pd.read_csv('trends_20251101_010051.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0  Economic Growth             term  fetch_date  \
# 0           0             42.0  Economic Growth  2025-11-01
# 1           1             90.0  Economic Growth  2025-11-01
# 2           2             51.0  Economic Growth  2025-11-01
# 3           3             48.0  Economic Growth  2025-11-01
# 4           4             60.0  Economic Growth  2025-11-01
#
#    Economic Situation  Economy  Employment  Employment Rate  \
# 0                 NaN      NaN         NaN              NaN
# 1                 NaN      NaN         NaN              NaN
# 2                 NaN      NaN         NaN              NaN
# 3                 NaN      NaN         NaN              NaN
# 4                 NaN      NaN         NaN              NaN
#
#    Employment Situation  Expenditure  ...  Stocks  Taxes  Tourist Attractions  \
# 0                   NaN          NaN  ...     NaN    NaN                  NaN
# 1                   NaN          NaN  ...     NaN    NaN                  NaN
# ...

# %%
df1.shape
# Out:
# (10292, 65)

# %%
df1.columns.values
# Out:
# array(['Unnamed: 0', 'Economic Growth', 'term', 'fetch_date',
#        'Economic Situation', 'Economy', 'Employment', 'Employment Rate',
#        'Employment Situation', 'Expenditure', 'Failure',
#        'Financial Investment', 'Financial Markets', 'Financing',
#        'Food Price', 'Foreign Exchange Rate', 'Gasoline Prices',
#        'Housing Prices', 'Import and Export', 'Income',
#        'Industrial Value Added', 'Inflation', 'Interest Rate',
#        'Interest Rate Cut', 'International Settlement',
#        'International Trade', 'Investment', 'Labour',
#        'Macroeconomic Control', 'Medical Care', 'Monetary Policy',
#        'Money Supply', 'Mortgage', 'National Economy', 'Oil Prices',
#        'Peanut Oil Prices', 'Population', 'Pork Price', 'Prices',
#        'Production', 'Public Debt', 'Purchase', 'Quality of Life',
#        'RMB Exchange Rate', 'Recession', 'Recovery',
#        'Refrigerator Prices', 'Rent', 'Retirement', 'Sales', 'Saving',
# ...

# %%
data=pd.DataFrame()

for i in df1.columns.values:
    data[i]=df1[i][df1[i].notna()]

# %%
df1[df1.notna()]
# Out:
#        Unnamed: 0  Economic Growth                   term  fetch_date  \
# 0               0             42.0        Economic Growth  2025-11-01
# 1               1             90.0        Economic Growth  2025-11-01
# 2               2             51.0        Economic Growth  2025-11-01
# 3               3             48.0        Economic Growth  2025-11-01
# 4               4             60.0        Economic Growth  2025-11-01
# ...           ...              ...                    ...         ...
# 10287       10287              NaN  Washing Machine Price  2025-11-01
# 10288       10288              NaN  Washing Machine Price  2025-11-01
# 10289       10289              NaN  Washing Machine Price  2025-11-01
# 10290       10290              NaN  Washing Machine Price  2025-11-01
# 10291       10291              NaN  Washing Machine Price  2025-11-01
#
#        Economic Situation  Economy  Employment  Employment Rate  \
# ...

# %%
df1['Economic Growth'][df1['Economic Growth'].notna()]
# Out:
# 0      42.0
# 1      90.0
# 2      51.0
# 3      48.0
# 4      60.0
#        ...
# 161    31.0
# 162    31.0
# 163    32.0
# 164    51.0
# 165    23.0
# Name: Economic Growth, Length: 166, dtype: float64

# %%
12*13+10
# Out:
# 166

# %%
25-12
# Out:
# 13
