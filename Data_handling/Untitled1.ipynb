# %% [markdown]
# | **Day**       | **Brief Description of Work Carried Out**                                                                                                                                                                                                                       |
# | ------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **Monday**    | Assigned a project: *Finding a novel method for CCI index calculation using Google Trends (GT) data.* Studied the background of the project — what CCI is and what GT data represent. Reviewed existing CCI indices for Sri Lanka and their methodologies.      |
# | **Tuesday**   | Searched for research papers on different approaches to developing the CCI index and studied their methodologies, including how they fetched GT data.                                                                                                           |
# | **Wednesday** | Studied GT data, methods of extraction, and the various challenges encountered when fetching GT data, as well as how researchers overcame these challenges. Read GT data documentation and related research papers on GT data preprocessing.                    |
# | **Thursday**  | Attempted GT data extraction using the Pytrends library but encountered errors due to data-fetching limitations. Explored possible remedies for these limitations.                                                                                              |
# | **Friday**    | Assigned another new project: *Web scraping the TopJobs website to find the number of job openings for each category.* Analyzed the structure of the TopJobs website, identified challenges in web scraping, and began initial testing of the scraping process. |

# %% [markdown]
# **Reflective Lessons Learned Through the Week**
#
# * Gained a clear understanding of how the CCI index is developed and the importance of using Google Trends data for economic analysis.
# * Learned how to access and preprocess GT data, and understood the challenges and limitations involved in fetching it.
# * Improved problem-solving skills by finding solutions to technical issues with the Pytrends library.
# * Enhanced research skills through reading and analyzing multiple research papers and methodologies.
# * Gained hands-on experience in web scraping and learned how to handle website structure and data extraction challenges.

# %% [markdown]
# | **Day**       | **Brief Description of Work Carried Out**                                                                                                                                                                                                                                      |
# | ------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ |
# | **Monday**    | Tried different OCR methods and explored free packages that can extract text from job posters, with the goal of identifying the number of job openings from the extracted text. Also explored LLMs that can be used to determine the number of job openings in a given poster. |
# | **Tuesday**   | Created a full workflow for processing a given image and identifying the job openings count. Tested the method on various posters to check its performance and identify challenges.                                                                                            |
# | **Wednesday** | Developed a complete workflow to scrape job listings from a selected category within a given timeframe from the TopJobs website, extract information from each job poster, and identify the number of job openings. Also created an interface to test this system.             |
# | **Thursday**  | Read research papers on developing the CCI index using Google Trends (GT) data. Identified relevant keywords needed for data fetching and studied the keyword selection methods used in previous research.                                                                     |
# | **Friday**    | Created a set of keywords based on research papers and additional terms relevant to Sri Lanka. Worked on resolving the errors encountered when fetching GT data due to Google’s limitations, and developed an automated system to fetch GT data every four hours using GitHub. |

# %% [markdown]
# **Reflective Lessons Learned Through the Week**
#
# * Gained hands-on experience in applying OCR techniques to extract meaningful text data from images.
# * Learned how Large Language Models (LLMs) can be used to interpret text and extract specific information such as job counts.
# * Improved understanding of web scraping workflows and how to automate data extraction from websites like TopJobs.
# * Enhanced research and analytical skills by studying different methodologies for developing the CCI index using Google Trends data.
# * Learned how to identify and select effective keywords for GT-based research.
# * Strengthened problem-solving and automation skills by creating a GitHub-based system to fetch GT data periodically and handle API limitations.

# %% [markdown]
# Here’s a clear and polished **two-week summary** version of your work description:
#
# ---
#
# ### **Brief Description of Work Carried Out (Two-Week Period)**
#
# During this period, I was assigned two main projects. The first project focused on developing a novel method for calculating the Consumer Confidence Index (CCI) using Google Trends (GT) data. I began by studying the background of the project, including the concept of CCI, the nature of GT data, and existing CCI indices and methodologies used in Sri Lanka. I then reviewed several research papers to understand different approaches for constructing CCI indices, identifing key words that can be used and the methods used for acquiring and preprocessing GT data. I explored GT data extraction using the Pytrends library, identifying challenges such as data-fetching limitations and testing possible solutions to overcome them. In the second project, I was assigned to perform web scraping of the TopJobs website to determine the number of job openings for each job category. I analyzed the website’s structure, identified potential scraping challenges, and initiated preliminary implementation of the web scraping process.
#
# ---
#
# Would you like me to make this more **formal and compact** (for a university logbook or official report), or keep it in this **narrative style**?

# %% [markdown]
# Here’s the corrected and polished version of your **Problems and Solutions** section:
#
# ---
#
# **Problems and Solutions**
#
# **Problem 1:** It was difficult to interpret the meaning of Google Trends (GT) data values and understand their normalization process.
# **Solution:** Studied the Google Trends documentation and relevant academic papers to understand data scaling, normalization methods, and how to make GT data suitable for index calculation.
#
# **Problem 2:** GT data extraction limitations — while using the Pytrends library to fetch Google Trends data, requests often failed due to rate limits and regional data unavailability.
# **Solution:** Implemented GitHub automation to run the code every 4 hours and save the fetched data into a CSV file to gradually collect the full dataset.
#
# **Problem 3:** Some job posts on the TopJobs website did not specify the exact number of job openings.
# **Solution:** Extracted text from job posters using OCR techniques and used text analysis to estimate or identify the number of job openings mentioned.
#
# ---
#
# Would you like me to combine this with your previous “Reflective Lessons Learned” section into a single formatted report page?
